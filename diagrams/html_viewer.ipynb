# %% [markdown]
# This is supportive notebook for html artefacts. Github does not support html pages as source files. The simplest way is using HTML Preview without cloning or downloading:
# - https://html-preview.github.io/?url=https://github.com/banban/architecture-as-code/blob/main/diagrams/oil_gas_ai_capability_map.html
# - https://html-preview.github.io/?url=https://github.com/banban/architecture-as-code/blob/main/diagrams/oil_gas_ai_tech_class_map.html
# - https://html-preview.github.io/?url=https://github.com/banban/architecture-as-code/blob/main/diagrams/atam_assessment.html
#
# We can also use github pages deployed by hithub actions, as we did for Archi models.\
# Another quick option is to render html in the notebook like the following. It renders locally and Jupiter cloud enfironments, but looks ugly on the github repo page.

# %%
from IPython.display import HTML
HTML(filename='oil_gas_ai_capability_map.html')
# Out:
# <style>
#   * { box-sizing: border-box; margin: 0; padding: 0; }
#   body { font-family: var(--font-sans, 'Segoe UI', Arial, sans-serif); }
#   .root { padding: 16px; background: #f5f5f0; min-width: 1400px; }
#   .main-title { font-size: 22px; font-weight: 700; color: #1a1a2e; letter-spacing: 0.5px; margin-bottom: 18px; text-transform: uppercase; border-left: 5px solid #1a3a6b; padding-left: 12px; }
#   .section-label { font-size: 11px; font-weight: 700; text-align: center; color: #444; text-transform: uppercase; letter-spacing: 1px; margin-bottom: 6px; }
#   .top-sections { display: flex; gap: 8px; margin-bottom: 8px; }
#   /* EXPLORATION & PRODUCTION */
#   .ep-section { flex: 0 0 auto; width: 560px; }
#   .ep-header { background: #1a3a6b; color: #fff; font-size: 11px; font-weight: 700; text-align: center; padding: 4px 6px; border-radius: 4px 4px 0 0; letter-spacing: 0.5px; text-transform: uppercase; }
#   /* TRANSPORT */
#   .tr-section { flex: 0 0 auto; width: 380px; }
# ...

# %%
HTML(filename='oil_gas_ai_tech_class_map.html')
# Out:
# <style>
#   * { box-sizing: border-box; margin: 0; padding: 0; }
#   .root { padding: 16px; background: #f5f5f0; min-width: 1350px; font-family: var(--font-sans, 'Segoe UI', Arial, sans-serif); }
#   .main-title { font-size: 20px; font-weight: 700; color: #1a1a2e; letter-spacing: 0.4px; margin-bottom: 18px; text-transform: uppercase; border-left: 5px solid #1a3a6b; padding-left: 12px; }
#   .grid-wrap { display: flex; gap: 3px; }
#   .col { flex: 1; display: flex; flex-direction: column; gap: 3px; }
#   .col-head { color: #fff; font-size: 9.5px; font-weight: 700; text-align: center; padding: 8px 5px; border-radius: 4px 4px 0 0; line-height: 1.3; min-height: 54px; display: flex; align-items: center; justify-content: center; position: relative; }
#   .star { position: absolute; top: -10px; left: 50%; transform: translateX(-50%); font-size: 18px; color: #4a9fd4; line-height: 1; }
# ...

# %%
HTML(filename='atam_assessment.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="UTF-8"/>
# <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
# <title>ATAM Architecture Assessment</title>
# <link href="https://fonts.googleapis.com/css2?family=Sora:wght@300;400;600;700;800&family=JetBrains+Mono:wght@400;700&display=swap" rel="stylesheet"/>
# <style>
#   *{box-sizing:border-box;margin:0;padding:0;}
#   body{font-family:'Sora','Segoe UI',sans-serif;background:#f1f5f9;color:#1e293b;min-height:100vh;}
#   ::-webkit-scrollbar{width:6px;height:6px;}
#   ::-webkit-scrollbar-track{background:#e2e8f0;}
#   ::-webkit-scrollbar-thumb{background:#94a3b8;border-radius:3px;}
#
#   /* HEADER */
#   .header{background:linear-gradient(135deg,#ffffff 0%,#f8fafc 100%);border-bottom:1px solid #e2e8f0;padding:32px 40px 24px;box-shadow:0 1px 4px rgba(0,0,0,0.06);}
#   .header-top{display:flex;align-items:flex-start;justify-content:space-between;flex-wrap:wrap;gap:16px;}
# ...
