# %%
import base64
from IPython.display import Image, display

def render_mermaid(graph_code):
    graphbytes = graph_code.encode("ascii")
    base64_bytes = base64.b64encode(graphbytes)
    base64_string = base64_bytes.decode("ascii")
    display(Image(url="https://mermaid.ink/img/" + base64_string))

# %% [markdown]
# Now, we can generate diagrams. More examples https://mermaid.live/edit

# %%
render_mermaid("""
graph TD
    Start --> Stop
""")
# Out:
# <img src="https://mermaid.ink/img/CmdyYXBoIFRECiAgICBTdGFydCAtLT4gU3RvcAo="/>
